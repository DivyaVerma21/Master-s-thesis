# %% [markdown]
# <a href="https://colab.research.google.com/github/DivyaVerma21/Master-s-thesis/blob/main/Word_cloud_thematic_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt


answers = [
    # Q1
    ["The main effect would be to make cheating easy.", "Administrators around setting up new courses and making course plans, it efficient by creating a good first draft.", "I think it should be incorporated into the teaching instead of fighting, embrace it. It should be a part of teaching to guide how to access it for good.", "They can be a support, automating certain tasks and creating learning material and background resources.", "Knowledge about how to effectively use AI tools can be used to fix tasks that don’t require personal resources.", "AI can help teachers to make better teaching plans and for administrative staff, it can help to find better information and help with automating routine tasks.", "I am positive. As a tool for assistance, inspire students to grasp complex concepts."],
    # Q2
    ["The main limitation is that the output looks plausible but has random arbitrary errors that are hard to detect.", "Rely most on AI and not use the same amount of time reflecting.", "The free version is not so good and reliable. The paid version costs money.", "I think AI will not replace our practices, but the tools will affect and change the way we work.", "Lack of knowledge about how to use it.", "People must think of their values and must put themselves to be able to sensibly use AI.", "Not reliable, accurate. More confusions."],
    # Q3
    ["Like chatbots can improve search engines, plagiarism-detecting software can be improved.", "Send in/upload documents so that AI can check sources and find similarities.", "Don’t think it can be prevented. No need to look for problems on that end. It is not plagiarism; it is still unique. They have been trained and so they are creating new.", "I don’t think it is possible to detect academic fraud using AI. However, it might be possible to use Gen AI to detect traditional plagiarism.", "Not applicable to my job.", "Can use sensors to detect and search for similar writings.", "Look for how it can be moderated. Question only if 100% sure that it is AI-generated."],
    # Q4
    ["AI-powered chatbots can generate scenarios/designs for the students to evaluate.", "Better writing skills, structured text, and better depth explanations than Google.", "Pretty much everything. Language completion esp. for non-native speakers. Faster brainstorming.", "I think AI tools can be used to automate certain processes and support academics like literature reviews, analytics, etc.", "Text improvement and automation.", "Online learning can be enjoyable with it. Researchers can also use AI chatbots to look for information faster.", "Need to study more and work more and not rely on 100%. Grasping concepts gets easier as it gives examples. One needs to be literate about the topic as it may give false information. Also, basic prompts often give non-satisfactory answers. Need to talk more and provide effective prompts to get good answers. One needs to question the chatbots and check if they are on the right path."],
    # Q5
    ["Discussions are always better than passive listening. Chatbot discussions have two problems. Those who like it are drawn further into the virtual world away from the real human world. The rest may simply feel unmotivated, due to a lack of attention from humans.", "Better step-by-step explanation of the issues. Shorter time to search.", "In a very positive way. Helps to write better. Quick brainstorming. More efficient by helping us improve our weaknesses.", "I hope it will have a positive impact, empowering students to find information and negotiate in the world around them. However, if used wrongly, AI can hide information resulting in less literacy and more dependence on such AI tools. It depends on how the tools are used.", "Not an area I am familiar with.", "Both negative and positive. Depends on how the students use it. If used instead of doing things on their own, it's negative but if used as a companion or helping tool, it's positive.", "Learn the tool to use it. It depends on the student’s ability, and one must understand the capability to get the best out of it."],
    # Q6
     ["AI chatbots should work under some guidelines in order to serve us better and good for our privacy too.", "The AI-powered Chatbots themselves are fine as they are for good prompters. What is truly needed is education in proper use for common people.", "I think that the future for AI is bright Slong as there's guidelines amongst its uses I hope that we get to see it get to the point where its also like the home assistant market yet doesn't cross any ethical borders and also gets a proper guidance on How's its going to operate",
"Many people might not know how to efficiently use it to learn, and instead use it to do work ,which is often inaccurate",
"I feel AI-powered chatbots are great for studying, but it should not be fully used to complete an assignment. But it is great for research and for looking up what different terms means. But i always double check the information it gives me.",
"In the long run, it can stop newer generations in using their mind and own abilities to find answers on how things should be done, while leaving everything to an AI. This could create a generation of people who believe in everything an AI tells them, without checking if the information they got is actually true.",
"It's amazing.",
"The major concerns are similar to that of any ML system including: 1. Over-dependence on ML models and minimal to no human involvement  2. Data privacy issues  3. Reliability - Hallucinations are still not solved so for critical application the chatbots can still not be used.    Suggestions for improvements:  1. Using personalized and open-source models with transfer learning instead of out of the box models.  2. Having a good MLOps infrastructure in place before starting with LLM based chatbots.",
"It's useful only for learning purpose.",
"AI chatbots should work under some guidelines in order to serve us better and good for our privacy too.",
"Data protection.",
"I feel like the chatbots can be improved more by having relevant context throughout the conversations.",
"How do they work & where are the sources are undisclosed and important topics",
"I just have a general huge distaste for anything AI. And I think it diminishes creativity and it ruins learning. More often than not it feels like whenever somebody uses AI, it's almost like a 'get out of jail free'-card, as in they did nothing to come to the information they found and it's they do not learn anything from it, it doesnot stick in their heads. It is like cheating on a test or copying someone else's homework, you learn nothing and it's unethical.","I just have a general huge distaste for anything AI. And I think it diminishes creativity and it ruins learning. More often than not it feels like whenever somebody uses AI, it's almost like a 'get out of jail free'-card, as in they did nothing to come to the information they found and it's they do not learn anything from it, it doesnot stick in their heads. It is like cheating on a test or copying someone else's homework, you learn nothing and it's unethical","I just have a general huge distaste for anything AI. And I think it diminishes creativity and it ruins learning. More often than not it feels like whenever somebody uses AI, it's almost like a 'get out of jail free'-card, as in they did nothing to come to the information they found and it's they do not learn anything from it, it doesnot stick in their heads. It is like cheating on a test or copying someone else's homework, you learn nothing and it's unethical.","I just have a general huge distaste for anything AI. And I think it diminishes creativity and it ruins learning. More often than not it feels like whenever somebody uses AI, it's almost like a 'get out of jail free'-card, as in they did nothing to come to the information they found and it's they do not learn anything from it, it doesnot stick in their heads. It is like cheating on a test or copying someone else's homework, you learn nothing and it's unethical."
]
]

for i, q_answers in enumerate(answers, start=1):

    text = " ".join(q_answers)


    wordcloud = WordCloud(width=800, height=400, background_color="white").generate(text)


    plt.figure(figsize=(10, 5))
    plt.imshow(wordcloud, interpolation="bilinear")
    plt.axis("off")
    plt.title(f"Word Cloud for Q{i}")
    plt.show()
